# %% [markdown]
# # Data Understanding

# %%
#%matplotlib inline
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
#import seaborn as sns


hr_dataset = pd.read_csv("HR_comma_sep.csv")
hr_dataset.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# sales                     object
# salary                    object
# dtype: object

# %%
hr_dataset.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
hr_dataset.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
hr_dataset['sales'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_dataset['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
hr_dataset['number_project'].unique()
# Out:
# array([2, 5, 7, 6, 4, 3])

# %%
hr_dataset['left'].unique()
# Out:
# array([1, 0])

# %%
hr_dataset['promotion_last_5years'].unique()
# Out:
# array([0, 1])

# %%
hr_dataset['Work_accident'].unique()
# Out:
# array([0, 1])

# %%
hr_dataset['sales'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_dataset.boxplot(column="number_project")
plt.show()
hr_dataset.boxplot(column="last_evaluation")
plt.show()
hr_dataset.boxplot(column="time_spend_company")
plt.show()
hr_dataset.boxplot(column="satisfaction_level")
plt.show()
hr_dataset.boxplot(column="average_montly_hours")
plt.show()
hr_dataset.boxplot(column="last_evaluation")
plt.show()

# %%
hr_dataset.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
hr_dataset['salary'].value_counts().plot(kind='bar', title='Salary')
plt.xticks(rotation=0)
plt.show()

# %%
hr_dataset['number_project'].value_counts().plot(kind='bar', title='Number project')
plt.xticks(rotation=0)
plt.show()

# %%
hr_dataset['time_spend_company'].value_counts().plot(kind='bar', title='time_spend_company')
plt.xticks(rotation=0)
plt.show()

# %%
hr_dataset['left'].value_counts().plot(kind='bar', title='Left')
plt.xticks(rotation=0)
plt.show()

# %%
hr_dataset['Work_accident'].value_counts().plot(kind='bar', title='Work accident')
plt.xticks(rotation=0)
plt.show()

# %%
hr_dataset['promotion_last_5years'].value_counts().plot(kind='bar', title='promotion_last_5years')
plt.xticks(rotation=0)
plt.show()

# %%
hr_dataset["average_montly_hours"].hist(bins=10)
plt.show()

# %%
hr_dataset.isnull().any()
# Out:
# satisfaction_level       False
# last_evaluation          False
# number_project           False
# average_montly_hours     False
# time_spend_company       False
# Work_accident            False
# left                     False
# promotion_last_5years    False
# sales                    False
# salary                   False
# dtype: bool

# %%
hr_dataset.hist('satisfaction_level')
plt.xlabel('Satisfaction Level')
plt.ylabel('Number of Employees')
plt.title('Distribution of Satisfaction Levels')
plt.show()

# %%
hr_dataset.plot(kind='scatter',x='satisfaction_level',y='last_evaluation', label='Job Satisfaction vs Performance Appraisal', color='orchid', figsize=(20, 10)) 
plt.show()

# %%
pd.DataFrame.hist(hr_dataset, column="satisfaction_level", bins=10)
plt.show()

# %%
pd.DataFrame.hist(hr_dataset, column="average_montly_hours", bins=150, color = "red")
plt.show()

# %%
pd.DataFrame.hist(hr_dataset, column="last_evaluation", bins=150, color = "green")
plt.show()

# %%
hr_dataset['sales'].value_counts().plot(kind='bar', title='Sales', colormap = "winter")
plt.show()

# %%
#fig, axs = plt.subplots(ncols=2,figsize=(12,6))
#x = sns.countplot(hr_dataset['sales'], ax=axs[0])
#plt.setp(x.get_xticklabels(), rotation=45)
#y = sns.countplot(hr_dataset['salary'], ax=axs[1])
#plt.tight_layout()

# %%
#fig, axs = plt.subplots(ncols=2,figsize=(12,6))
#x = sns.countplot(hr_dataset['number_project'], ax=axs[0])
#plt.setp(x.get_xticklabels(), rotation=45)
#y = sns.countplot(hr_dataset['time_spend_company'], ax=axs[1])
#plt.tight_layout()

# %%
hr_dataset['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
hr_dataset['Work_accident'].value_counts()
# Out:
# 0    12830
# 1     2169
# Name: Work_accident, dtype: int64

# %%
hr_dataset['promotion_last_5years'].value_counts()
# Out:
# 0    14680
# 1      319
# Name: promotion_last_5years, dtype: int64

# %%
hr_dataset['sales'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: sales, dtype: int64

# %%
hr_dataset['salary'].value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
hr_dataset['time_spend_company'].value_counts()
# Out:
# 3     6443
# 2     3244
# 4     2557
# 5     1473
# 6      718
# 10     214
# 7      188
# 8      162
# Name: time_spend_company, dtype: int64

# %%
pd.scatter_matrix(hr_dataset[['last_evaluation', 'satisfaction_level', 'average_montly_hours', 'number_project']], figsize=(40, 40))
plt.show()
# Out:
# /Applications/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
